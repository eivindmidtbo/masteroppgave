# %% [markdown]
# # Check correlation between similarities based on grid-based hashes and true similarities

# %%
# from correlation import compute_correlation_similarity
from grid_resolution import plot_grid_res_layers

# %% [markdown]
# # Plot Pearson correlation coefficient with various layers and resolution

# %% [markdown]
# ## Grid Rome

# %%
plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4],
    resolution=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6, 8, 10],
    resolution=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4],
    resolution=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6, 8, 10],
    resolution=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=10,
)
# Out:
# L: 4 2.80
# L: 1 1.20

# %% [markdown]
# ## Grid Porto

# %%
plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 5, 0.2],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4, 5, 6, 8, 10],
    resolution=[0.2, 5, 0.2],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 5, 0.2],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=10,
)

plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4, 5, 6, 8, 10],
    resolution=[0.2, 5, 0.2],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=3,
)

# %% [markdown]
# ## Grid Kolumbus

# %%
plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 5, 0.4],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=3,
)

plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 5, 0.4],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=3,
)

# plot_grid_res_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6, 8, 10],
#     [0.2, 5, 0.2],
#     parallell_jobs=20,
#     reference="dtw",
# )

# plot_grid_res_layers(
#     "kolumbus", [1, 2, 3, 4], [0.2, 5, 0.2], parallell_jobs=20, reference="frechet"
# )

# plot_grid_res_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6, 8, 10],
#     [0.2, 5, 0.2],
#     parallell_jobs=20,
#     reference="frechet",
# )
# Out:
# L: 4 4.60
# L: 1 0.20

# %% [markdown]
# # Correlation variance

# %%
# compute_correlation_similarity("porto", "grid", 5)
