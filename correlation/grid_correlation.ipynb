# %% [markdown]
# # Check correlation between similarities based on grid-based hashes and true similarities

# %%
# from correlation import compute_correlation_similarity
from grid_resolution import plot_grid_res_layers

# %% [markdown]
# # Plot Pearson correlation coefficient with various layers and resolution

# %% [markdown]
# ## Grid Rome

# %% [markdown]
# #### DTW

# %%
plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="dtw",
    parallel_jobs=3,
)


plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="frechet",
    parallel_jobs=3,
)
# Out:
# L: 5 1.80
# L: 1 0.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       1 plot_grid_res_layers(
#       2     city="rome",
#       3     layers=[1, 2, 3, 4, 5],
#    (...)
#       7     parallel_jobs=3,
#       8 )
# ---> 11 plot_grid_res_layers(
#      12     city="rome",
#      13     layers=[1, 2, 3, 4, 5],
#      14     resolution=[0.2, 2, 0.2],
#      15     measure="dtw",
#      16     reference="frechet",
#      17     parallel_jobs=3,
#      18 )
#
# File ~/masteroppgave/masteroppgave/correlation/grid_resolution.py:231, in plot_grid_res_layers(city, layers, resolution, measure, reference, parallel_jobs)
#     205 def plot_grid_res_layers(
#     206     city: str,
#     207     layers: list[int],
#    (...)
#     211     parallel_jobs: int = 20,
#     212 ):
#     213     """Visualises the 'optimal' values for resolution and layers for the grid hashes
#     214
#     215     Param
#    (...)
#     228         Yhe number of parallel jobs that will create the data foundation
#     229     """
# --> 231     results = _compute_grid_res_layers(
#     232         city, layers, resolution, measure, reference, parallel_jobs
#     233     )
#     235     fig, ax1 = plt.subplots(figsize=(10, 8), dpi=300)
#     236     ax2 = ax1.twinx()
#
# File ~/masteroppgave/masteroppgave/correlation/grid_resolution.py:192, in _compute_grid_res_layers(city, layers, resolution, measure, reference, parallell_jobs)
#     188 print(f"L: {lay}", "{:.2f}".format(res), end="\r")
#     189 # edits = _mirrorDiagonal(MEASURE[measure](hashes)).flatten()
#     190
#     191 # corr = np.corrcoef(edits, REFERENCE[city.lower()+reference.lower()])[0][1]
# --> 192 corrs = pool.map(
#     193     _fun_wrapper_corr,
#     194     [(city, res, lay, measure, reference) for _ in range(parallell_jobs)],
#     195 )
#     196 corr = np.average(np.array(corrs))
#     197 std = np.std(np.array(corrs))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Fréchet

# %%
plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2.2, 0.4],
    measure="frechet",
    reference="dtw",
    parallel_jobs=3,
)


plot_grid_res_layers(
    city="rome",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2, 0.2],
    measure="frechet",
    reference="frechet",
    parallel_jobs=3,
)
# Out:
# L: 4 1.80
# L: 4 1.80

# %% [markdown]
# ## Grid Porto

# %% [markdown]
# #### DTW

# %%
plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="dtw",
    parallel_jobs=3,
)

plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="frechet",
    parallel_jobs=3,
)

# %% [markdown]
# #### Fréchet

# %%
plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2.2, 0.4],
    measure="frechet",
    reference="dtw",
    parallel_jobs=3,
)


plot_grid_res_layers(
    city="porto",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2.2, 0.4],
    measure="frechet",
    reference="frechet",
    parallel_jobs=3,
)
# Out:
# L: 4 1.80
# L: 4 1.80

# %% [markdown]
# ## Grid Kolumbus

# %% [markdown]
# #### DTW

# %%
plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="dtw",
    parallel_jobs=3,
)

plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4, 5],
    resolution=[0.2, 2, 0.2],
    measure="dtw",
    reference="frechet",
    parallel_jobs=3,
)

# %% [markdown]
# #### Fréchet

# %%
plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2.2, 0.4],
    measure="frechet",
    reference="dtw",
    parallel_jobs=3,
)

plot_grid_res_layers(
    city="kolumbus",
    layers=[1, 2, 3, 4],
    resolution=[0.2, 2.2, 0.4],
    measure="frechet",
    reference="frechet",
    parallel_jobs=3,
)
# Out:
# L: 4 1.80
# L: 4 1.80

# %% [markdown]
# # Correlation variance

# %%
# compute_correlation_similarity("porto", "grid", 5)
