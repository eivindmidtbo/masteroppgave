# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
# from grid_resolution import plot_grid_sizes
from disk_resolution import plot_disk_numbers

# %% [markdown]
# ## Disk

# %% [markdown]
# #### DTW

# %%
plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# Skipped comparisons for disk number 30: 13.52%
# Skipped comparisons for disk number 40: 6.29%
# Skipped comparisons for disk number 50: 3.80%
# Skipped comparisons for disk number 60: 1.27%
# Skipped comparisons for disk number 70: 0.79%
# Skipped comparisons for disk number 80: 0.25%
# Skipped comparisons for disk number 90: 0.05%
# Skipped comparisons for disk number 100: 0.00%
# Skipped comparisons for disk number 110: 0.00%
# Skipped comparisons for disk number 120: 0.00%
# Skipped comparisons for disk number 130: 0.00%
# Skipped comparisons for disk number 140: 0.00%
# Skipped comparisons for disk number 150: 0.00%

# %%
plot_disk_numbers(
    city="porto",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# Skipped comparisons for disk number 30: 25.38%
# Skipped comparisons for disk number 40: 15.92%
# Skipped comparisons for disk number 50: 10.90%
# Skipped comparisons for disk number 60: 8.76%
# Skipped comparisons for disk number 70: 4.09%
# Skipped comparisons for disk number 80: 3.37%
# Skipped comparisons for disk number 90: 1.97%
# Skipped comparisons for disk number 100: 1.48%
# Skipped comparisons for disk number 110: 1.53%
# Skipped comparisons for disk number 120: 0.93%
# Skipped comparisons for disk number 130: 1.04%
# Skipped comparisons for disk number 140: 0.99%
# Skipped comparisons for disk number 150: 0.64%

# %%
plot_disk_numbers(
    city="kolumbus",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# Skipped comparisons for disk number 30: 57.86%
# Skipped comparisons for disk number 40: 49.60%
# Skipped comparisons for disk number 50: 44.07%
# Skipped comparisons for disk number 60: 31.47%
# Skipped comparisons for disk number 70: 28.28%
# Skipped comparisons for disk number 80: 29.50%
# Skipped comparisons for disk number 90: 27.99%
# Skipped comparisons for disk number 100: 22.29%
# Skipped comparisons for disk number 110: 19.90%
# Skipped comparisons for disk number 120: 16.50%
# Skipped comparisons for disk number 130: 16.04%
# Skipped comparisons for disk number 140: 16.39%
# Skipped comparisons for disk number 150: 13.13%
