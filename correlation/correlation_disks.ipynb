# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
# from grid_resolution import plot_grid_sizes
from disk_resolution import plot_disk_numbers

# %% [markdown]
# ## Grid

# %% [markdown]
# #### DTW

# %%
plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="dtw",
    sizes=[50, 100, 200, 300, 400, 500],
    parallel_jobs=10,
)

plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="frechet",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_grid_sizes(
#       2     layer=2,
#       3     resolution=1.0,
#       4     measure="dtw",
#       5     reference="dtw",
#       6     sizes=[50, 100, 200, 300, 400, 500],
#       7     parallel_jobs=10,
#       8 )
#      10 plot_grid_sizes(
#      11     layer=2,
#      12     resolution=1.0,
#    (...)
#      16     parallel_jobs=10,
#      17 )
#
# NameError: name 'plot_grid_sizes' is not defined

# %% [markdown]
# #### Fréchet

# %%
plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="frechet",
    reference="dtw",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)

plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="frechet",
    reference="frechet",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)

# %% [markdown]
# ## Disk

# %% [markdown]
# #### DTW

# %%
plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=1.0,
    disks=[50, 100, 200, 300, 400, 500],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# DN: 500DN: 400
