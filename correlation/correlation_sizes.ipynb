# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
from grid_resolution import plot_grid_sizes
from disk_resolution import plot_disk_sizes

# %% [markdown]
# ## Grid

# %% [markdown]
# #### DTW

# %%
plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="dtw",
    sizes=[50, 100, 200, 300, 400, 500],
    parallel_jobs=10,
)

plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="frechet",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)
# Out:
# Size: 50 for porto
# Size: 100 for porto
# Size: 200 for porto
# Size: 300 for porto
# Size: 400 for porto
# Size: 500 for porto
# Size: 50 for rome
# Size: 100 for rome
# Size: 200 for rome
# Size: 300 for rome
# Size: 400 for rome
# Size: 500 for rome
# Size: 50 for kolumbus
# Size: 100 for kolumbus
# Size: 200 for kolumbus
# Size: 300 for kolumbus
# Size: 400 for kolumbus
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_grid_sizes(
#       2     layer=2,
#       3     resolution=1.0,
#       4     measure="dtw",
#       5     reference="dtw",
#       6     sizes=[50, 100, 200, 300, 400, 500],
#       7     parallel_jobs=10,
#       8 )
#      10 plot_grid_sizes(
#      11     layer=2,
#      12     resolution=1.0,
#    (...)
#      16     parallel_jobs=10,
#      17 )
#
# File ~/masteroppgave/masteroppgave/correlation/grid_resolution.py:393, in plot_grid_sizes(layer, sizes, resolution, measure, reference, parallel_jobs)
#     391 datasets = ["porto", "rome", "kolumbus"]
#     392 for city in datasets:
# --> 393     results = _compute_grid_sizes(
#     394         city=city,
#     395         layer=layer,
#     396         resolution=resolution,
#     397         measure=measure,
#     398         reference=reference,
#     399         sizes=sizes,
#     400         parallel_jobs=parallel_jobs,
#     401     )
#     402     all_results.append(results)
#     403 # print("All results: ", all_results)
#
# File ~/masteroppgave/masteroppgave/correlation/grid_resolution.py:367, in _compute_grid_sizes(city, layer, resolution, measure, reference, sizes, parallel_jobs)
#     365 for size in sizes:
#     366     print(f"Size: {size} for {city}")
# --> 367     corrs = pool.map(
#     368         _fun_wrapper_corr_sizes,
#     369         [
#     370             (city, resolution, layer, measure, reference, size)
#     371             for _ in range(parallel_jobs)
#     372         ],
#     373     )
#     374     corr = np.average(np.array(corrs))
#     375     std = np.std(np.array(corrs))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Fréchet

# %%
plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="frechet",
    reference="dtw",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)

plot_grid_sizes(
    layer=2,
    resolution=1.0,
    measure="frechet",
    reference="frechet",
    sizes=[50, 100, 200],
    parallel_jobs=10,
)

# %% [markdown]
# ## Disk

# %% [markdown]
# #### DTW

# %%
plot_disk_sizes(
    layer=4,
    resolution=1.5,
    number_of_disks=50,
    sizes=[50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# Size: 50 for porto
# Size: 100 for porto
# Size: 200 for porto
# Size: 300 for porto
# Size: 400 for porto
# Size: 500 for porto
# Size: 600 for porto
# Size: 700 for porto
# Size: 800 for porto
# Size: 900 for porto
# Size: 1000 for porto
# Size: 50 for rome
# Size: 100 for rome
# Size: 200 for rome
# Size: 300 for rome
# Size: 400 for rome
# Size: 500 for rome
# Size: 600 for rome
# Size: 700 for rome
# Size: 800 for rome
# Size: 900 for rome
# Size: 1000 for rome
# Size: 50 for kolumbus
# Size: 100 for kolumbus
# Size: 200 for kolumbus
# Size: 300 for kolumbus
# Size: 400 for kolumbus
# Size: 500 for kolumbus
# Size: 600 for kolumbus
# Size: 700 for kolumbus
# Size: 800 for kolumbus
# Size: 900 for kolumbus
# Size: 1000 for kolumbus
