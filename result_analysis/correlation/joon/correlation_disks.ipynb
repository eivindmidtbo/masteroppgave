# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
# from grid_resolution import plot_grid_sizes
from disk_resolution import plot_disk_numbers

# %% [markdown]
# ## Disk

# %% [markdown]
# #### DTW

# %%
plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=2.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="porto",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="porto",
    layers=4,
    diameter=2.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="dtw",
    reference="dtw",
    parallel_jobs=10,
)
# Out:
# Skipped comparisons for disk number 30: 14.23%
# Skipped comparisons for disk number 40: 5.92%
# Skipped comparisons for disk number 50: 3.17%
# Skipped comparisons for disk number 60: 1.42%
# Skipped comparisons for disk number 70: 0.44%
# Skipped comparisons for disk number 80: 0.05%
# Skipped comparisons for disk number 90: 0.05%
# Skipped comparisons for disk number 100: 0.15%
# Skipped comparisons for disk number 110: 0.00%
# Skipped comparisons for disk number 120: 0.00%
# Skipped comparisons for disk number 130: 0.00%
# Skipped comparisons for disk number 140: 0.00%
# Skipped comparisons for disk number 150: 0.00%
# Skipped comparisons for disk number 30: 0.49%
# Skipped comparisons for disk number 40: 0.15%
# Skipped comparisons for disk number 50: 0.00%
# Skipped comparisons for disk number 60: 0.00%
# Skipped comparisons for disk number 70: 0.00%
# Skipped comparisons for disk number 80: 0.00%
# Skipped comparisons for disk number 90: 0.00%
# ...

# %%
plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="frechet",
    reference="frechet",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="rome",
    layers=4,
    diameter=2.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="frechet",
    reference="frechet",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="porto",
    layers=4,
    diameter=1.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="frechet",
    reference="frechet",
    parallel_jobs=10,
)

plot_disk_numbers(
    city="porto",
    layers=4,
    diameter=2.0,
    disks=[30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150],
    measure="frechet",
    reference="frechet",
    parallel_jobs=10,
)
# Out:
# Skipped comparisons for disk number 30: 12.76%
# Skipped comparisons for disk number 40: 5.37%
# Skipped comparisons for disk number 50: 2.40%
# Skipped comparisons for disk number 60: 1.77%
# Skipped comparisons for disk number 70: 0.30%
# Skipped comparisons for disk number 80: 0.05%
# Skipped comparisons for disk number 90: 0.00%
# Skipped comparisons for disk number 100: 0.00%
# Skipped comparisons for disk number 110: 0.05%
# Skipped comparisons for disk number 120: 0.00%
# Skipped comparisons for disk number 130: 0.00%
# Skipped comparisons for disk number 140: 0.00%
# Skipped comparisons for disk number 150: 0.00%
# Skipped comparisons for disk number 30: 0.54%
# Skipped comparisons for disk number 40: 0.20%
# Skipped comparisons for disk number 50: 0.00%
# Skipped comparisons for disk number 60: 0.00%
# Skipped comparisons for disk number 70: 0.00%
# Skipped comparisons for disk number 80: 0.00%
# Skipped comparisons for disk number 90: 0.00%
# ...
